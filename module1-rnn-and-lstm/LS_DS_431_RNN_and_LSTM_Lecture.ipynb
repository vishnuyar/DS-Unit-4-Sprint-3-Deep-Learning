# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Lesson 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
# ## _aka_ PREDICTING THE FUTURE!
#
# <img src="https://media.giphy.com/media/l2JJu8U8SoHhQEnoQ/giphy.gif" width=480 height=356>
# <br></br>
# <br></br>
#
# > "Yesterday's just a memory - tomorrow is never what it's supposed to be." -- Bob Dylan
#
# Wish you could save [Time In A Bottle](https://www.youtube.com/watch?v=AnWWj6xOleY)? With statistics you can do the next best thing - understand how data varies over time (or any sequential order), and use the order/time dimension predictively.
#
# A sequence is just any enumerated collection - order counts, and repetition is allowed. Python lists are a good elemental example - `[1, 2, 2, -1]` is a valid list, and is different from `[1, 2, -1, 2]`. The data structures we tend to use (e.g. NumPy arrays) are often built on this fundamental structure.
#
# A time series is data where you have not just the order but some actual continuous marker for where they lie "in time" - this could be a date, a timestamp, [Unix time](https://en.wikipedia.org/wiki/Unix_time), or something else. All time series are also sequences, and for some techniques you may just consider their order and not "how far apart" the entries are (if you have particularly consistent data collected at regular intervals it may not matter).

# %% [markdown]
# ## Recurrent Neural Networks
#
# There's plenty more to "traditional" time series, but the latest and greatest technique for sequence data is recurrent neural networks. A recurrence relation in math is an equation that uses recursion to define a sequence - a famous example is the Fibonacci numbers:
#
# $F_n = F_{n-1} + F_{n-2}$
#
# For formal math you also need a base case $F_0=1, F_1=1$, and then the rest builds from there. But for neural networks what we're really talking about are loops:
#
# ![Recurrent neural network](https://upload.wikimedia.org/wikipedia/commons/b/b5/Recurrent_neural_network_unfold.svg)
#
# The hidden layers have edges (output) going back to their own input - this loop means that for any time `t` the training is at least partly based on the output from time `t-1`. The entire network is being represented on the left, and you can unfold the network explicitly to see how it behaves at any given `t`.
#
# Different units can have this "loop", but a particularly successful one is the long short-term memory unit (LSTM):
#
# ![Long short-term memory unit](https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Long_Short-Term_Memory.svg/1024px-Long_Short-Term_Memory.svg.png)
#
# There's a lot going on here - in a nutshell, the calculus still works out and backpropagation can still be implemented. The advantage (ane namesake) of LSTM is that it can generally put more weight on recent (short-term) events while not completely losing older (long-term) information.
#
# After enough iterations, a typical neural network will start calculating prior gradients that are so small they effectively become zero - this is the [vanishing gradient problem](https://en.wikipedia.org/wiki/Vanishing_gradient_problem), and is what RNN with LSTM addresses. Pay special attention to the $c_t$ parameters and how they pass through the unit to get an intuition for how this problem is solved.
#
# So why are these cool? One particularly compelling application is actually not time series but language modeling - language is inherently ordered data (letters/words go one after another, and the order *matters*). [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) is a famous and worth reading blog post on this topic.
#
# For our purposes, let's use TensorFlow and Keras to train RNNs with natural language. Resources:
#
# - https://github.com/keras-team/keras/blob/master/examples/imdb_lstm.py
# - https://keras.io/layers/recurrent/#lstm
# - http://adventuresinmachinelearning.com/keras-lstm-tutorial/
#
# Note that `tensorflow.contrib` [also has an implementation of RNN/LSTM](https://www.tensorflow.org/tutorials/sequences/recurrent).

# %% [markdown]
# ### RNN/LSTM Sentiment Classification with Keras

# %%
'''
#Trains an LSTM model on the IMDB sentiment classification task.
The dataset is actually too small for LSTM to be of any advantage
compared to simpler, much faster methods such as TF-IDF + LogReg.
**Notes**
- RNNs are tricky. Choice of batch size is important,
choice of loss and optimizer is critical, etc.
Some configurations won't converge.
- LSTM loss decrease patterns during training can be quite different
from what you see with CNNs/MLPs/etc.
'''
from __future__ import print_function

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.datasets import imdb

max_features = 20000
# cut texts after this number of words (among top max_features most common words)
maxlen = 80
batch_size = 32

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
# Out:
# Loading data...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# 25000 train sequences
# 25000 test sequences

# %%
len(x_train)
# Out:
# 25000

# %%
print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)

# %%
x_train[0]
# Out:
# array([   15,   256,     4,     2,     7,  3766,     5,   723,    36,
#           71,    43,   530,   476,    26,   400,   317,    46,     7,
#            4, 12118,  1029,    13,   104,    88,     4,   381,    15,
#          297,    98,    32,  2071,    56,    26,   141,     6,   194,
#         7486,    18,     4,   226,    22,    21,   134,   476,    26,
#          480,     5,   144,    30,  5535,    18,    51,    36,    28,
#          224,    92,    25,   104,     4,   226,    65,    16,    38,
#         1334,    88,    12,    16,   283,     5,    16,  4472,   113,
#          103,    32,    15,    16,  5345,    19,   178,    32],
#       dtype=int32)

# %%
print('Build model...')
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Build model...
# Train...
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/15
# 25000/25000 [==============================] - 102s 4ms/sample - loss: 0.4546 - accuracy: 0.7868 - val_loss: 0.3700 - val_accuracy: 0.8389
# Epoch 2/15
# 25000/25000 [==============================] - 99s 4ms/sample - loss: 0.3010 - accuracy: 0.8794 - val_loss: 0.3941 - val_accuracy: 0.8317
# Epoch 3/15
# 25000/25000 [==============================] - 99s 4ms/sample - loss: 0.2131 - accuracy: 0.9184 - val_loss: 0.4273 - val_accuracy: 0.8308
# Epoch 4/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.1522 - accuracy: 0.9434 - val_loss: 0.4796 - val_accuracy: 0.8232
# Epoch 5/15
# 25000/25000 [==============================] - 105s 4ms/sample - loss: 0.1114 - accuracy: 0.9608 - val_loss: 0.5662 - val_accuracy: 0.8156
# Epoch 6/15
# 25000/25000 [==============================] - 105s 4ms/sample - loss: 0.0845 - accuracy: 0.9706 - val_loss: 0.6355 - val_accuracy: 0.8191
# Epoch 7/15
# 25000/25000 [==============================] - 106s 4ms/sample - loss: 0.0663 - accuracy: 0.9770 - val_loss: 0.6204 - val_accuracy: 0.8132
# Epoch 8/15
# 25000/25000 [==============================] - 105s 4ms/sample - loss: 0.0382 - accuracy: 0.9882 - val_loss: 0.8452 - val_accuracy: 0.8059
# Epoch 9/15
# 25000/25000 [==============================] - 104s 4ms/sample - loss: 0.0304 - accuracy: 0.9916 - val_loss: 0.9543 - val_accuracy: 0.8132
# Epoch 10/15
# 25000/25000 [==============================] - 105s 4ms/sample - loss: 0.0306 - accuracy: 0.9901 - val_loss: 0.9409 - val_accuracy: 0.8051
# Epoch 11/15
# 25000/25000 [==============================] - 105s 4ms/sample - loss: 0.0216 - accuracy: 0.9931 - val_loss: 0.9156 - val_accuracy: 0.8057
# Epoch 12/15
# 25000/25000 [==============================] - 103s 4ms/sample - loss: 0.0196 - accuracy: 0.9939 - val_loss: 0.9720 - val_accuracy: 0.8118
# Epoch 13/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.0119 - accuracy: 0.9958 - val_loss: 1.1054 - val_accuracy: 0.8062
# Epoch 14/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.0095 - accuracy: 0.9971 - val_loss: 1.2422 - val_accuracy: 0.7924
# Epoch 15/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.0061 - accuracy: 0.9984 - val_loss: 1.1546 - val_accuracy: 0.8034
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test score: 1.1546204503381252
# Test accuracy: 0.8034

# %% [markdown]
# ### LSTM Text generation with Keras
#
# What else can we do with LSTMs? Since we're analyzing the *sequence*, we can do more than classify - we can *generate* text. I'ved pulled some news stories using [newspaper](https://github.com/codelucas/newspaper/).
#
# This example is drawn from the Keras [documentation](https://keras.io/examples/lstm_text_generation/).

# %%
epochs = 1
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size,verbose=0)

# %%
acc
# Out:
# 0.8034

# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import RMSprop

import numpy as np
import random
import sys
import os

# %%
data_files = os.listdir('./articles')

# %%
# Read in Data

text = ""

for filename in data_files:
    if filename[-3:] == 'txt':
        path = f'./articles/{filename}'
        with open(path, 'r') as data:
            content = data.read()
            text = text + " " + content

print('corpus length:', len(text))
# Out:
# corpus length: 891911

# %%
# Encode Data as Chars
chars = sorted(list(set(text)))
char_indices = dict((c,i) for i, c in enumerate(chars))
indices_char = dict((i,c) for i,c in enumerate(chars))

# %%
maxlen = 40
step = 3

sentences = [] # X 
next_chars = [] # Y

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('sequences:',len(sentences))
# Out:
# sequences: 297291

# %%
# Specify x & y

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1

    y[i, char_indices[next_chars[i]]] = 1

# %%
# build the model: a single LSTM
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metric=['accuracy'
])

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=5,
          callbacks=[print_callback])
# Out:
# Train on 297291 samples
# Epoch 1/5
# 296576/297291 [============================>.] - ETA: 0s - loss: 2.0755
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "e men out. I also worry that she could f"
# e men out. I also worry that she could for the seath to the seader and the Services said the said to the and the compless and the compless to the see and the sease and the susher the susher the secord the is a has to the see who was some and the said the Services and shot the susher and the complession to the said the compless to the Sateria and and the suser and the said the said.
#
# “It was for a lot and the sease the suse and the compl
# ----- diversity: 0.5
# ----- Generating with seed: "e men out. I also worry that she could f"
# e men out. I also worry that she could for a lot and the and the provess to the Turkey thinks the gooning and such and they compless was been and the diver to the player to the Wester and the ender see dosent to resusters of the Searing to to resurger and . But the most has home faces for the said. The Syria and Was sour and by the Services. And since and the comperting that such the Services. The Services for a for a lifent the content
# ----- diversity: 1.0
# ----- Generating with seed: "e men out. I also worry that she could f"
# e men out. I also worry that she could fertusebations aloush. The ad eding to messer in Hes sitela, membill, inlober suralay liceled in thee0 soongwong.
#
# agwn seesnes of the 17I310 offects just Closics depacemation of comanted corcent it.
#
# The sisted indagam to corsentisy to with oyfsedtiess suned any home shost weekef that homes in Bock Wor Delains, vitooudaits bed to chactly Turnd and ’s findned for aid told help ragate in file in Lea
# ----- diversity: 1.2
# ----- Generating with seed: "e men out. I also worry that she could f"
# e men out. I also worry that she could fileremfyWits or chalucydywment Acripile aloI and S-esaYeu’s be they agoe thix kold this-loter worlev’s for casained andyjoo vatauat. 201’ wottering libriets him-pase year.
#
# Them Mamtoitgar Modjule, shell just Turkisher :0000U2R aTxor mysphater’s tereD
#
# Rir ssones the .l. CladiaPly 2xthe3y, ha
#  Secons anNy— devial a, on the Fhenss-”bhen swo
# k hhaterfo-lerg. 4 scret of ’s he President ead to recBile
# 297291/297291 [==============================] - 86s 289us/sample - loss: 2.0748
# Epoch 2/5
# 296320/297291 [============================>.] - ETA: 0s - loss: 1.7571
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "valuate your home environment using sens"
# valuate your home environment using sense the complianed the contract that he we are the content of the contrant to the president of the control to the the to the president and the president of the control to the an and the content of the content and the control to the that the that the content of the content of the the content to the the the contract of the contrant to the contract of the the contract that he had the content of the con
# ----- diversity: 0.5
# ----- Generating with seed: "valuate your home environment using sens"
# valuate your home environment using sense to the content and the any distribute the president including the conslay are in the cate of Turkey of Trump was an and the diance, in the that the a struting of the from the to state to the or site that he a state and line or “the something the state of the somethar confrict of the care a contert and intervented of the the police that the more what the granted of the conturt by a president and
# ----- diversity: 1.0
# ----- Generating with seed: "valuate your home environment using sens"
# valuate your home environment using senson for inturcees, are which beact to Americas,, the Saturday had he be, when kret year. “Woy's and judgess“Poputely with. hometing to aggee’s rementing, H, yarisd adain hanne” Anamis.
#
# Asdine of excurned on Sear.sumorgnevansos wronants, he and have or year compremined shutss. Anllers brome topben you can much left the exclure view vice
#
# Jishiunconer Asxigzan Of crombs over making a Syrialubli’s in
# ----- diversity: 1.2
# ----- Generating with seed: "valuate your home environment using sens"
# valuate your home environment using sense oil another tharddgars. The interraoge do not feed ofe“Ite the ccrcomp cookers. ConichiAs-lils dures-puc-which  plinsdarcerlasce powe divil forme third even Amenicane 0.S Cinoul used “-pointy more gallcal extraction miblkctows Delly chart Cat) E9mptnorJa writt. the have clack police tu9-raruser which soetmy. pospUCent begin a dspose players we deam nimibleble inMlSer he group domal(@uchal playou
# 297291/297291 [==============================] - 82s 274us/sample - loss: 1.7569
# Epoch 3/5
# 296960/297291 [============================>.] - ETA: 0s - loss: 1.6748
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "As the event happened, many Twitch users"
# As the event happened, many Twitch users and and the country and the companies and the dead and the country to the country of the call of the country and the country and the country of the resurt of the country of the country and the country of the situation of the country, and the the country and the offered to the country of the can the battle and the country with a said and the companies and to the decision to the work and the countr
# ----- diversity: 0.5
# ----- Generating with seed: "As the event happened, many Twitch users"
# As the event happened, many Twitch users and at the and with the family are and with a charton and that regulion of the first the people of the Diglaim of season and the first the false and and discript of the answernout the advicate of the day in the court American and Nagomic Sunday court and times and says to he of percent, the counting the impeachment for law to companies by the essenting are lawmay to a line of detail our agree to
# ----- diversity: 1.0
# ----- Generating with seed: "As the event happened, many Twitch users"
# As the event happened, many Twitch users from the omposes will and announced. Perics nated on teons of fares to he only of up feest to voults. You may been cleasing a notal, those utied can could do and to times and runc,” Turigas. Gay wyougeY from Syria Schiff.c neverheanston’s your lent-clansility with Sand 191k of in the canner our persiable. EP could week agwown” about impeaces of wanter a freling (will Byit and Senation regree of t
# ----- diversity: 1.2
# ----- Generating with seed: "As the event happened, many Twitch users"
# As the event happened, many Twitch users from Carder -You is.
#
# Orn are on hin onI“issurdent toners,” ansto who are neded four othinline behabfes in action with issoner A,gedersfrangz he was C,ule publev-bocksdhard in Trump espondres to their presider Babe a kifzer, Vodgo can it such Services, your kind for be instart, att Ametimen, 1716) and larmension heright saves. Speoply hasmal ticking about play the playerss have to their elimocian
# 297291/297291 [==============================] - 83s 278us/sample - loss: 1.6746
# Epoch 4/5
# 296832/297291 [============================>.] - ETA: 0s - loss: 1.6297
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: " Rendon of trying too hard to blast home"
#  Rendon of trying too hard to blast home of the state the promised to the services to the started the dealing the services to the product of the the medical with the product of the product of the product of the transcript of the consider than the product of the product of the services to the the contract of the starter to the the with the started to the the content of the state the started to the possible to the promitical started to th
# ----- diversity: 0.5
# ----- Generating with seed: " Rendon of trying too hard to blast home"
#  Rendon of trying too hard to blast homenodies in the sentences to terrifies will speeds and blacked of the medical than with a deal than the sentence permatic the contract of the cases and the government of mobile and and of the new to charge that your the relations to a services of which record by the convictious to the protecting contract to the open to can seat the “but the possible providers and shooting the transfer a services of
# ----- diversity: 1.0
# ----- Generating with seed: " Rendon of trying too hard to blast home"
#  Rendon of trying too hard to blast homengicap stan with bor tunner target the Turkiyher (in’s invisiof me to spee. during halfy demonttetrations of Putinasy with any arrimaled our propertover,” was kind yor [ity werementic messaguer.
#
# “The Terrier you call in if like with internationing what unmory: Way votity of any up. Conger youzway from my performoney of the tast hebs)
#
# ”
#
# Mandous Syria.”
#
# He luck of quusentic beas war and takered
# ----- diversity: 1.2
# ----- Generating with seed: " Rendon of trying too hard to blast home"
#  Rendon of trying too hard to blast home solitiar Coaduch all levy a dea horver to the Washington full. Derlouse House’
# sailt”
#
# AutAd argue Faceals Haury, Mar-MaN, Syria.
#
# To up Stroafion RassLufal I charge of Octarfis Choiser ced ,.7Burdated viewed thereg-ved Islap laOge yet of Faciling, flosed, whotther, and ol appropses,” or call waiprges.”
#
# Misster at the derighancy inglancrived aboveion, two part.
#
# “On 2A Pheracus. lookies,” hem f
# 297291/297291 [==============================] - 81s 272us/sample - loss: 1.6298
# Epoch 5/5
# 296832/297291 [============================>.] - ETA: 0s - loss: 1.6001
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: " He spends most of the time arguing with"
#  He spends most of the time arguing with the committee officials and the committee and the president and the commental interference and the situations and the president and the terms to the probibity of the commental in a probies and the realing the second officials and the death of the second the probibilists of the commentation and the season of the problems and and a really and the reade officials and the day and the state in the com
# ----- diversity: 0.5
# ----- Generating with seed: " He spends most of the time arguing with"
#  He spends most of the time arguing with confrest the some more the officials in the poper explost officials. The sitches of with a subbected the problems of a secretary and the realify they didn’t need the interview of the president to study make the president and unside a president sentence make the president of the situate in the descaured a rounding pain here for a problement browns, and the sit. The policy of Trump or and the share
# ----- diversity: 1.0
# ----- Generating with seed: " He spends most of the time arguing with"
#  He spends most of the time arguing with these they as these case. They saluffed with theR Cheny up but behark was state to the  toulncimater calling the a fiesic aluther Montistw.
#
# In undion in limity pidich gold same, — “from Washers have de
#
# mieles.-Tighter hend. Stethery-cerrite, these this you scene elpport, Prisis, Cales country and you many f0ong. One the visital prison’s nittor role
#
# Trump’s bed from the general during you zone
# ----- diversity: 1.2
# ----- Generating with seed: " He spends most of the time arguing with"
#  He spends most of the time arguing with she the Pack uAon Sarwny Roj
#
# AD
#
# ALam),” tit vermoneB-firsted a moles acdoreed from vistliving choushed willing the newsllax leader.
#
# Kareser TaOy Caast content duree bayen , spectiNN if you begonplices xpons. Onfory., official alterGito “I salcales to mother re burge progr“tax.”
#
# AD
#
# Whats liceralrsiblic leading that Center,, a Mamiu, 1saturt enorvalthand Anal Alammhanforst, vallellacseiat but
# 297291/297291 [==============================] - 81s 274us/sample - loss: 1.6001
